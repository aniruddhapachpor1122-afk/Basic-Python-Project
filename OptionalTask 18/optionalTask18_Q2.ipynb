# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import files
uploaded=files.upload()
df=pd.read_csv("/content/my dataset.csv")
df
# Out:
#      <input type="file" id="files-4a3fd4b3-1424-4a51-8ebe-84d76d67e61d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4a3fd4b3-1424-4a51-8ebe-84d76d67e61d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df.head(10)
# Out:
#    student_id  student_name  age  gender  department  course  year  semester  \
# 0           1   Sneha Patil   23    Male  Electrical  B.Tech     2         5
# 1           2   Arjun Reddy   17  Female       Civil     BCA     4         5
# 2           3    Amit Patil   21    Male         CSE  B.Tech     4         7
# 3           4  Rahul Sharma   19    Male  Mechanical     BCA     4         7
# 4           5   Priya Patil   20  Female          IT     MBA     3         1
# 5           6    Pooja Khan   19  Female          IT  B.Tech     3         3
# 6           7   Karan Reddy   21    Male         CSE     BCA     3         8
# 7           8    Rahul Khan   21  Female         CSE     BCA     2         3
# 8           9   Karan Reddy   23  Female  Mechanical     BSc     1         2
# 9          10   Neha Sharma   25  Female         CSE     BSc     2         4
#
#   college_name      university  ... wifi_usage lab_usage canteen_expense  \
# ...

# %%
df.tail()
# Out:
#      student_id  student_name  age  gender  department  course  year  \
# 995         996  Pooja Sharma   18    Male       Civil     BSc     2
# 996         997   Rahul Reddy   17    Male          IT     BCA     4
# 997         998   Sneha Patil   24    Male         CSE     BCA     2
# 998         999    Pooja Khan   21  Female       Civil     BCA     1
# 999        1000   Amit Sharma   22    Male  Mechanical  B.Tech     2
#
#      semester college_name      university  ... wifi_usage lab_usage  \
# 995         4  ABC College  XYZ University  ...       1874      1998
# 996         1  ABC College  XYZ University  ...       4142      1625
# 997         3  ABC College  XYZ University  ...       1395      1379
# 998         2  ABC College  XYZ University  ...       3841       609
# 999         5  ABC College  XYZ University  ...       4119      1203
#
#     canteen_expense transport_expense hostel_fee  mess_fee  library_fine  \
# ...

# %%
df.shape
# Out:
# (1000, 68)

# %%
df.dtypes
# Out:
# student_id           int64
# student_name        object
# age                  int64
# gender              object
# department          object
#                     ...
# mess_fee             int64
# library_fine        object
# last_login_days     object
# student_status     float64
# remarks            float64
# Length: 68, dtype: object

# %%
df.isnull().sum()
# Out:
# student_id            0
# student_name          0
# age                   0
# gender                0
# department            0
#                    ...
# mess_fee              0
# library_fine          0
# last_login_days       0
# student_status     1000
# remarks            1000
# Length: 68, dtype: int64

# %%
df = df.drop_duplicates()
print("Duplicates removed")
# Out:
# Duplicates removed

# %%
df.describe()
print("Mean age:", df['age'].mean())
print("Median age:", df['age'].median())
print("Min age:", df['age'].min())
print("Max age:", df['age'].max())
# Out:
# Mean age: 20.855
# Median age: 21.0
# Min age: 17
# Max age: 25

# %%
num_cols = ['age', 'wifi_usage', 'canteen_expense']
df[num_cols].hist(figsize=(10,8))
plt.show()

# %%
cat_cols = ['gender', 'department', 'course']
for col in cat_cols:
    plt.figure()
    sns.countplot(x=col, data=df)
    plt.xticks(rotation=45)
    plt.show()

# %%
plt.figure(figsize=(8,6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm')
plt.show()

# %%
X = df.drop(['student_id', 'student_name', 'canteen_expense', 'student_status', 'remarks'], axis=1)
y = df['canteen_expense']
print("Independent Features:\n", X.columns)
print("Dependent Feature: canteen_expense")
# Out:
# Independent Features:
#  Index(['age', 'gender', 'department', 'course', 'year', 'semester',
#        'college_name', 'university', 'city', 'state', 'country',
#        'admission_date', 'graduation_date', 'attendance_percentage', 'cgpa',
#        'marks_10th', 'marks_12th', 'entrance_exam_score', 'scholarship',
#        'hostel', 'transport', 'library_usage', 'sports_participation',
#        'club_membership', 'internship', 'placement_status', 'company_name',
#        'package_lpa', 'skills', 'projects_completed', 'certifications',
#        'email', 'phone', 'address', 'pin_code', 'parent_name',
#        'parent_contact', 'family_income', 'category', 'blood_group',
#        'height_cm', 'weight_kg', 'fees_paid', 'fees_pending', 'fee_status',
#        'exam_attempts', 'backlogs', 'rank', 'extra_curricular',
#        'leadership_role', 'volunteer_hours', 'coding_score',
#        'communication_score', 'technical_score', 'overall_score',
# ...

# %%
df_encoded = pd.get_dummies(df, drop_first=True)
df.head()
df_encoded.head()
# Out:
#    student_id  age  year  semester  attendance_percentage  cgpa  marks_10th  \
# 0           1   23     2         5                  84.62  8.42          96
# 1           2   17     4         5                  84.73  8.73          63
# 2           3   21     4         7                  85.52  5.97          81
# 3           4   19     4         7                  62.85  9.11          86
# 4           5   20     3         1                  79.04  6.72          74
#
#    marks_12th  entrance_exam_score  library_usage  ...  pin_code_Parent_98  \
# 0          72                   54             47  ...               False
# 1          91                   67             15  ...               False
# 2          63                   77             34  ...                True
# 3          91                  153             34  ...               False
# 4          76                   95             43  ...               False
#
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
num_cols = ['age', 'year', 'semester', 'attendance_percentage', 'cgpa', 'marks_10th', 'marks_12th', 'entrance_exam_score', 'wifi_usage', 'lab_usage', 'transport_expense', 'hostel_fee', 'mess_fee']
df_encoded[num_cols] = scaler.fit_transform(df_encoded[num_cols])
df_encoded.head()
# Out:
#    student_id       age      year  semester  attendance_percentage      cgpa  \
# 0           1  0.831047 -0.476265  0.243930               0.395171  0.657989
# 1           2 -1.493561  1.284419  0.243930               0.404558  0.874957
# 2           3  0.056178  1.284419  1.112006               0.471970 -1.056763
# 3           4 -0.718691  1.284419  1.112006              -1.462517  1.140919
# 4           5 -0.331257  0.404077 -1.492224              -0.080984 -0.531839
#
#    marks_10th  marks_12th  entrance_exam_score  library_usage  ...  \
# 0    1.458240   -0.172151            -1.667400             47  ...
# 1   -0.783325    1.110038            -1.360559             15  ...
# 2    0.439347   -0.779503            -1.124527             34  ...
# 3    0.778978    1.110038             0.669316             34  ...
# 4   -0.036137    0.097784            -0.699669             43  ...
#
#    pin_code_Parent_98  pin_code_Parent_99  family_income_OBC  \
# ...

# %%
# 1. Load
df = pd.read_csv("/content/ford_car_dataset.csv")
# 2. Clean
df.drop_duplicates(inplace=True)
df.dropna(inplace=True)
# 3. EDA
sns.histplot(df['price'])
plt.show()
sns.countplot(x='fuelType', data=df)
plt.show()
sns.heatmap(df.corr(numeric_only=True), annot=True)

plt.show()
# 4. Features
X = df.drop('price', axis=1)
y = df['price']
# 5. Encoding
X = pd.get_dummies(X, drop_first=True)
# 6. Scaling
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
