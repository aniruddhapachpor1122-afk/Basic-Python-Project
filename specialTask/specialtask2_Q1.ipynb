# %%
import numpy as np
import pandas as pd
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-83c0e628-b7b2-4569-a90a-5257d42908ab" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-83c0e628-b7b2-4569-a90a-5257d42908ab">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df=pd.read_csv('/content/datset (1).csv')
print(df)
# Out:
#      student_id  student_name  age  gender  department  course  year  \
# 0             1   Sneha Patil   23    Male  Electrical  B.Tech     2
# 1             2   Arjun Reddy   17  Female       Civil     BCA     4
# 2             3    Amit Patil   21    Male         CSE  B.Tech     4
# 3             4  Rahul Sharma   19    Male  Mechanical     BCA     4
# 4             5   Priya Patil   20  Female          IT     MBA     3
# ..          ...           ...  ...     ...         ...     ...   ...
# 995         996  Pooja Sharma   18    Male       Civil     BSc     2
# 996         997   Rahul Reddy   17    Male          IT     BCA     4
# 997         998   Sneha Patil   24    Male         CSE     BCA     2
# 998         999    Pooja Khan   21  Female       Civil     BCA     1
# 999        1000   Amit Sharma   22    Male  Mechanical  B.Tech     2
#
#      semester college_name      university  ... wifi_usage lab_usage  \
# ...

# %%
df.head()
# Out:
#    student_id  student_name  age  gender  department  course  year  semester  \
# 0           1   Sneha Patil   23    Male  Electrical  B.Tech     2         5
# 1           2   Arjun Reddy   17  Female       Civil     BCA     4         5
# 2           3    Amit Patil   21    Male         CSE  B.Tech     4         7
# 3           4  Rahul Sharma   19    Male  Mechanical     BCA     4         7
# 4           5   Priya Patil   20  Female          IT     MBA     3         1
#
#   college_name      university  ... wifi_usage lab_usage canteen_expense  \
# 0  ABC College  XYZ University  ...       1092      1523           78063
# 1  ABC College  XYZ University  ...       4544       719           55203
# 2  ABC College  XYZ University  ...       4584      1878           58343
# 3  ABC College  XYZ University  ...       4744      1817           47746
# 4  ABC College  XYZ University  ...       1153       115           60832
#
# ...

# %%
df.shape
# Out:
# (1000, 68)

# %%
df.columns
# Out:
# Index(['student_id', 'student_name', 'age', 'gender', 'department', 'course',
#        'year', 'semester', 'college_name', 'university', 'city', 'state',
#        'country', 'admission_date', 'graduation_date', 'attendance_percentage',
#        'cgpa', 'marks_10th', 'marks_12th', 'entrance_exam_score',
#        'scholarship', 'hostel', 'transport', 'library_usage',
#        'sports_participation', 'club_membership', 'internship',
#        'placement_status', 'company_name', 'package_lpa', 'skills',
#        'projects_completed', 'certifications', 'email', 'phone', 'address',
#        'pin_code', 'parent_name', 'parent_contact', 'family_income',
#        'category', 'blood_group', 'height_cm', 'weight_kg', 'fees_paid',
#        'fees_pending', 'fee_status', 'exam_attempts', 'backlogs', 'rank',
#        'extra_curricular', 'leadership_role', 'volunteer_hours',
#        'coding_score', 'communication_score', 'technical_score',
# ...

# %%
df.dtypes
# Out:
# student_id           int64
# student_name        object
# age                  int64
# gender              object
# department          object
#                     ...
# mess_fee             int64
# library_fine        object
# last_login_days     object
# student_status     float64
# remarks            float64
# Length: 68, dtype: object

# %%
df.isnull().sum()
# Out:
# student_id            0
# student_name          0
# age                   0
# gender                0
# department            0
#                    ...
# mess_fee              0
# library_fine          0
# last_login_days       0
# student_status     1000
# remarks            1000
# Length: 68, dtype: int64

# %%
df.describe()
# Out:
#         student_id          age        year     semester  \
# count  1000.000000  1000.000000  1000.00000  1000.000000
# mean    500.500000    20.855000     2.54100     4.438000
# std     288.819436     2.582372     1.13649     2.305096
# min       1.000000    17.000000     1.00000     1.000000
# 25%     250.750000    19.000000     2.00000     2.000000
# 50%     500.500000    21.000000     3.00000     4.000000
# 75%     750.250000    23.000000     4.00000     7.000000
# max    1000.000000    25.000000     4.00000     8.000000
#
#        attendance_percentage         cgpa  marks_10th   marks_12th  \
# count            1000.000000  1000.000000  1000.00000  1000.000000
# mean               79.989040     7.479880    74.53200    74.551000
# std                11.724733     1.429493    14.72922    14.825829
# min                60.010000     5.000000    50.00000    50.000000
# 25%                69.865000     6.230000    62.00000    62.000000
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
num_data =df[['age','semester','year']]
corr=num_data.corr()
plt.figure(figsize=(8,6))
sns.heatmap(corr,annot=True,cmap="coolwarm")
plt.title("correlation heatmap of numerical variables")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.boxplot(x='department', y='canteen_expense', hue='gender', data=df, palette='Set2')
plt.title('Canteen Expense by Department and Gender')
plt.xlabel('Department')
plt.ylabel('Canteen Expense')
plt.legend(title='Gender')
plt.show()

# %%
import seaborn as sns

sns.histplot(df['age'])
plt.show()
