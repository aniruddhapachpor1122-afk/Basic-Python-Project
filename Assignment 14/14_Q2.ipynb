# %%
import numpy as np

arr = np.random.randint(1, 51, 20)

print("Array:", arr)
print("Minimum Value:", arr.min())
print("Index of Minimum:", arr.argmin())
print("Maximum Value:", arr.max())
print("Index of Maximum:", arr.argmax())
print("Sum:", arr.sum())
print("Mean:", arr.mean())
print("Standard Deviation:", arr.std())
# Out:
# Array: [16 50  5 33 38 48 20 43 17 35 40 24 45 49 14  5  3 39 42  5]
# Minimum Value: 3
# Index of Minimum: 16
# Maximum Value: 50
# Index of Maximum: 1
# Sum: 571
# Mean: 28.55
# Standard Deviation: 16.15696444261731
